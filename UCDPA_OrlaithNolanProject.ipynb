# %%
import pandas as pd

# %%
import numpy as np

# %%
dataset = pd.read_csv("recruitment_decision_tree.csv")

# %%
dataset.head()
# Out:
#    Serial_no Gender Python_exp  Experience_Years     Education Internship  \
# 0          1   Male        Yes               0.0      Graduate         No
# 1          2   Male         No               1.0      Graduate         No
# 2          3   Male         No               0.0      Graduate        Yes
# 3          4   Male         No               0.0  Not Graduate         No
# 4          5   Male        Yes               0.0      Graduate         No
#
#    Score  Salary * 10E4  Offer_History Location Recruitment_Status
# 0   5139            0.0            1.0    Urban                  Y
# 1   4583          128.0            1.0    Rural                  N
# 2   3000           66.0            1.0    Urban                  Y
# 3   2583          120.0            1.0    Urban                  Y
# 4   6000          141.0            1.0    Urban                  Y

# %%
dataset.tail()
# Out:
#      Serial_no  Gender Python_exp  Experience_Years Education Internship  \
# 609        610  Female        Yes               0.0  Graduate         No
# 610        611    Male         No               3.0  Graduate         No
# 611        612    Male         No               1.0  Graduate         No
# 612        613    Male         No               2.0  Graduate         No
# 613        614  Female        Yes               0.0  Graduate        Yes
#
#      Score  Salary * 10E4  Offer_History   Location Recruitment_Status
# 609   2900           71.0            1.0      Rural                  Y
# 610   4106           40.0            1.0      Rural                  Y
# 611   8072          253.0            1.0      Urban                  Y
# 612   7583          187.0            1.0      Urban                  Y
# 613   4583          133.0            0.0  Semiurban                  N

# %%
dataset.head()
# Out:
#    Serial_no Gender Python_exp  Experience_Years     Education Internship  \
# 0          1   Male        Yes               0.0      Graduate         No
# 1          2   Male         No               1.0      Graduate         No
# 2          3   Male         No               0.0      Graduate        Yes
# 3          4   Male         No               0.0  Not Graduate         No
# 4          5   Male        Yes               0.0      Graduate         No
#
#    Score  Salary * 10E4  Offer_History Location Recruitment_Status
# 0   5139            0.0            1.0    Urban                  Y
# 1   4583          128.0            1.0    Rural                  N
# 2   3000           66.0            1.0    Urban                  Y
# 3   2583          120.0            1.0    Urban                  Y
# 4   6000          141.0            1.0    Urban                  Y

# %%
pd.set_option('display.max_rows', 500)

# %%
dataset.head(500)
# Out:
#      Serial_no  Gender Python_exp  Experience_Years     Education Internship  \
# 0            1    Male        Yes               0.0      Graduate         No
# 1            2    Male         No               1.0      Graduate         No
# 2            3    Male         No               0.0      Graduate        Yes
# 3            4    Male         No               0.0  Not Graduate         No
# 4            5    Male        Yes               0.0      Graduate         No
# 5            6    Male         No               2.0      Graduate        Yes
# 6            7    Male         No               0.0  Not Graduate         No
# 7            8    Male         No               3.0      Graduate         No
# 8            9    Male         No               2.0      Graduate         No
# 9           10    Male         No               1.0      Graduate         No
# 10          11    Male         No               2.0      Graduate         No
# ...

# %%
dataset.sort_values(by=['Gender', 'Education' ], ascending=False)
# Out:
#      Serial_no Gender Python_exp  Experience_Years     Education Internship  \
# 3            4   Male         No               0.0  Not Graduate         No
# 6            7   Male         No               0.0  Not Graduate         No
# 16          17   Male        Yes               1.0  Not Graduate         No
# 18          19   Male         No               0.0  Not Graduate         No
# 20          21   Male         No               0.0  Not Graduate         No
# ..         ...    ...        ...               ...           ...        ...
# 477        478    NaN         No               2.0      Graduate         No
# 507        508    NaN        Yes               0.0      Graduate         No
# 576        577    NaN         No               0.0      Graduate         No
# 588        589    NaN        Yes               0.0      Graduate         No
# 592        593    NaN        Yes               3.0      Graduate        Yes
#
# ...

# %%
dataset.sort_values(by=['Experience_Years', 'Gender', 'Education', 'Salary * 10E4'], ascending=[True, True, True, False], inplace=True)

# %%
dataset[['Experience_Years', 'Gender', 'Education']].head (500)
# Out:
#      Experience_Years  Gender     Education
# 233               0.0  Female      Graduate
# 119               0.0  Female      Graduate
# 148               0.0  Female      Graduate
# 210               0.0  Female      Graduate
# 404               0.0  Female      Graduate
# 559               0.0  Female      Graduate
# 382               0.0  Female      Graduate
# 116               0.0  Female      Graduate
# 298               0.0  Female      Graduate
# 37                0.0  Female      Graduate
# 49                0.0  Female      Graduate
# 111               0.0  Female      Graduate
# 96                0.0  Female      Graduate
# 122               0.0  Female      Graduate
# 69                0.0  Female      Graduate
# 306               0.0  Female      Graduate
# 268               0.0  Female      Graduate
# 613               0.0  Female      Graduate
# 323               0.0  Female      Graduate
# 302               0.0  Female      Graduate
# ...

# %%
dataset[['Experience_Years', 'Gender', 'Education', 'Salary * 10E4']].head (500)
# Out:
#      Experience_Years  Gender     Education  Salary * 10E4
# 233               0.0  Female      Graduate          280.0
# 119               0.0  Female      Graduate          259.0
# 148               0.0  Female      Graduate          225.0
# 210               0.0  Female      Graduate          214.0
# 404               0.0  Female      Graduate          194.0
# 559               0.0  Female      Graduate          182.0
# 382               0.0  Female      Graduate          156.0
# 116               0.0  Female      Graduate          154.0
# 298               0.0  Female      Graduate          151.0
# 37                0.0  Female      Graduate          144.0
# 49                0.0  Female      Graduate          144.0
# 111               0.0  Female      Graduate          139.0
# 96                0.0  Female      Graduate          137.0
# 122               0.0  Female      Graduate          137.0
# 69                0.0  Female      Graduate          136.0
# ...

# %%
dataset ['Salary * 10E4'] .nlargest(10)
# Out:
# 171    700.0
# 130    650.0
# 561    600.0
# 155    600.0
# 369    570.0
# 487    500.0
# 604    496.0
# 177    495.0
# 333    490.0
# 308    480.0
# Name: Salary * 10E4, dtype: float64

# %%
dataset.nlargest(10,'Salary * 10E4')
# Out:
#      Serial_no  Gender Python_exp  Experience_Years Education Internship  \
# 171        172     NaN         No               3.0  Graduate         No
# 130        131    Male        Yes               0.0  Graduate        Yes
# 561        562  Female         No               1.0  Graduate        Yes
# 155        156    Male         No               3.0  Graduate         No
# 369        370    Male         No               0.0  Graduate         No
# 487        488    Male         No               1.0  Graduate         No
# 604        605  Female         No               1.0  Graduate         No
# 177        178    Male         No               3.0  Graduate         No
# 333        334    Male         No               0.0  Graduate        NaN
# 308        309    Male        Yes               0.0  Graduate         No
#
#      Score  Salary * 10E4  Offer_History   Location Recruitment_Status
# 171  51763          700.0            1.0      Urban                  Y
# ...

# %%
dataset.head(500)
# Out:
#      Serial_no  Gender Python_exp  Experience_Years     Education Internship  \
# 233        234  Female        Yes               0.0      Graduate         No
# 119        120  Female        Yes               0.0      Graduate         No
# 148        149  Female        Yes               0.0      Graduate         No
# 210        211  Female        Yes               0.0      Graduate         No
# 404        405  Female        Yes               0.0      Graduate        Yes
# 559        560  Female         No               0.0      Graduate         No
# 382        383  Female        Yes               0.0      Graduate         No
# 116        117  Female         No               0.0      Graduate         No
# 298        299  Female        Yes               0.0      Graduate         No
# 37          38  Female         No               0.0      Graduate         No
# 49          50  Female        Yes               0.0      Graduate         No
# ...

# %%
dataset ['Salary * 10E4'].head (500)
# Out:
# 233    280.0
# 119    259.0
# 148    225.0
# 210    214.0
# 404    194.0
# 559    182.0
# 382    156.0
# 116    154.0
# 298    151.0
# 37     144.0
# 49     144.0
# 111    139.0
# 96     137.0
# 122    137.0
# 69     136.0
# 306    135.0
# 268    135.0
# 613    133.0
# 323    132.0
# 302    132.0
# 354    130.0
# 237    122.0
# 48     120.0
# 51     120.0
# 263    120.0
# 64     116.0
# 405    115.0
# 288    115.0
# 500    113.0
# 198    113.0
# 166    112.0
# 52     112.0
# 80     111.0
# 374    110.0
# 328    110.0
# 184    108.0
# 353    105.0
# 307    104.0
# 399    103.0
# 548    103.0
# 501    100.0
# 145    100.0
# 286     99.0
# 541     99.0
# 473     93.0
# 125     93.0
# 45      88.0
# 136     84.0
# 310     84.0
# 556     84.0
# 206     80.0
# 17      76.0
# 339     71.0
# 396     71.0
# 609     71.0
# 329     67.0
# 415     60.0
# 312     56.0
# 370     55.0
# 283     54.0
# 341     46.0
# 121     44.0
# 582     36.0
# 270     30.0
# 568      9.0
# 493    225.0
# ...

# %%
dataset ['Salary * 10E4'].median ()
# Out:
# 128.0

# %%
dataset.median()
# Out:
# Serial_no            307.5
# Experience_Years       0.0
# Score               3812.5
# Salary * 10E4        128.0
# Offer_History          1.0
# dtype: float64

# %%
dataset.describe()
# Out:
#         Serial_no  Experience_Years         Score  Salary * 10E4  \
# count  614.000000        599.000000    614.000000     593.000000
# mean   307.500000          0.762938   5402.302932     146.165261
# std    177.390811          1.015216   6109.024398      85.726110
# min      1.000000          0.000000    150.000000       0.000000
# 25%    154.250000          0.000000   2877.500000     100.000000
# 50%    307.500000          0.000000   3812.500000     128.000000
# 75%    460.750000          2.000000   5771.500000     168.000000
# max    614.000000          3.000000  81000.000000     700.000000
#
#        Offer_History
# count     564.000000
# mean        0.842199
# std         0.364878
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000

# %%
dataset['Python_exp']
# Out:
# 233    Yes
# 119    Yes
# 148    Yes
# 210    Yes
# 404    Yes
#       ...
# 102     No
# 346     No
# 226     No
# 517     No
# 301     No
# Name: Python_exp, Length: 614, dtype: object

# %%
dataset['Python_exp']. value_counts()
# Out:
# No     398
# Yes    213
# Name: Python_exp, dtype: int64

# %%
dataset['Location']. value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Location, dtype: int64

# %%
pd.set_option('display.max_rows', 500)

# %%
dataset.head(500)
# Out:
#      Serial_no  Gender Python_exp  Experience_Years     Education Internship  \
# 233        234  Female        Yes               0.0      Graduate         No
# 119        120  Female        Yes               0.0      Graduate         No
# 148        149  Female        Yes               0.0      Graduate         No
# 210        211  Female        Yes               0.0      Graduate         No
# 404        405  Female        Yes               0.0      Graduate        Yes
# 559        560  Female         No               0.0      Graduate         No
# 382        383  Female        Yes               0.0      Graduate         No
# 116        117  Female         No               0.0      Graduate         No
# 298        299  Female        Yes               0.0      Graduate         No
# 37          38  Female         No               0.0      Graduate         No
# 49          50  Female        Yes               0.0      Graduate         No
# ...

# %%
dataset.groupby (['Gender']) ["Offer_History",] .sum()
# Out:
#         Offer_History
# Gender
# Female           84.0
# Male            382.0

# %%
dataset.groupby (['Gender', 'Education', 'Internship']) ["Offer_History",] .sum()
# Out:
#                                 Offer_History
# Gender Education    Internship
# Female Graduate     No                   58.0
#                     Yes                   6.0
#        Not Graduate No                    9.0
#                     Yes                   4.0
# Male   Graduate     No                  247.0
#                     Yes                  41.0
#        Not Graduate No                   67.0
#                     Yes                   9.0

# %%
dataset.head(500)
# Out:
#      Serial_no  Gender Python_exp  Experience_Years     Education Internship  \
# 233        234  Female        Yes               0.0      Graduate         No
# 119        120  Female        Yes               0.0      Graduate         No
# 148        149  Female        Yes               0.0      Graduate         No
# 210        211  Female        Yes               0.0      Graduate         No
# 404        405  Female        Yes               0.0      Graduate        Yes
# 559        560  Female         No               0.0      Graduate         No
# 382        383  Female        Yes               0.0      Graduate         No
# 116        117  Female         No               0.0      Graduate         No
# 298        299  Female        Yes               0.0      Graduate         No
# 37          38  Female         No               0.0      Graduate         No
# 49          50  Female        Yes               0.0      Graduate         No
# ...

# %%
dataset['Serial_no']
# Out:
# 233    234
# 119    120
# 148    149
# 210    211
# 404    405
#       ...
# 102    103
# 346    347
# 226    227
# 517    518
# 301    302
# Name: Serial_no, Length: 614, dtype: int64

# %%
dataset.set_index('Serial_no', inplace=True)

# %%
dataset
# Out:
#            Gender Python_exp  Experience_Years     Education Internship  \
# Serial_no
# 234        Female        Yes               0.0      Graduate         No
# 120        Female        Yes               0.0      Graduate         No
# 149        Female        Yes               0.0      Graduate         No
# 211        Female        Yes               0.0      Graduate         No
# 405        Female        Yes               0.0      Graduate        Yes
# ...           ...        ...               ...           ...        ...
# 103          Male         No               NaN      Graduate         No
# 347          Male         No               NaN  Not Graduate         No
# 227          Male         No               NaN  Not Graduate        Yes
# 518          Male         No               NaN  Not Graduate         No
# 302          Male         No               NaN  Not Graduate         No
#
#            Score  Salary * 10E4  Offer_History   Location Recruitment_Status
# Serial_no
# ...
